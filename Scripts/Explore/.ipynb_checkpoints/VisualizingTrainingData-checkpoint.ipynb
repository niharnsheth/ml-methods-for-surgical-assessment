# %% [markdown]
# # VISUALIZING DATA #

# %%
# Script creates visual representations of data to determine nomalization parameters and
# appropriate filters for cleaning data

# --------------------------------------------------------------------------------------------------- #
## ---------------------      Import libraries and data       ------------------------ ##

# Run this cell first before running any other cells

import os
import fnmatch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
# Select surgery: 0 or 1
# 0 - Pericardiocentesis
# 1 - Thoracentesis
surgery_selected = 1

# File path to the database files
#source_path = os.getcwd() + '/../..' + '/Data/Data_04152021'
# source_path = os.getcwd() + '/../../Nihar/ML-data/SurgicalData'
source_path = os.getcwd() + '/../../Nihar/ML-data/SurgicalData/Manually_Cleaned_And_Annotated_06272021'
#save_to_folder = '/ThresholdFilter'

surgery_name_list = ['/Pericardiocentesis',
                     '/Thoracentesis']

# Get list of all data directories
#performance_list = os.listdir(source_path + surgery_name_list[surgery_selected] + '/')

sensor_id_list = ['0.csv', '1.csv', '2.csv', '3.csv']

# Determine the thresholds for normalization

## Import data for visualization
# obtain list of files

input_folder = '/ThresholdFilter'
save_to_folder = '/DataVisualization'

# Features List
column_name_list = ['X', 'Y', 'Z', 'W', 'Qx', 'Qy', 'Qz', 'Vx', 'Vy', 'Vz', 'VQx', 'VQy', 'VQz']
data_type_list = ['Position', 'Orientation', 'Linear_Velocity', 'Angular_Velocity']
action_list = ['Chloraprep', 'Scalpel_Incision', 'Trocar_Insertion', 'Anesthetizing']
# action_list = ['Chloraprep', 'Needle_Insertion']
# Out:
# Number of files: %d 40
# Found samples sucessfully !!

# %%
action_legends = [0,0,0]
fig, ax1 = plt.subplots()

main_df = pd.DataFrame()
seq_df = pd.DataFrame()

column_index = 3
column_name = column_name_list[3]
data_type = data_type_list[1] # type of data, position, velocity
action_selected = action_list[3] # surgical action
sensor_id = 3  # sensor Id
# Out:
# Knot_Tying_B001.txt
# File: Knot_Tying_B001.txt
# File: Knot_Tying_B002.txt
# File: Knot_Tying_B003.txt
# File: Knot_Tying_B004.txt
# D:\Documents\Nihar\virtual_env\unity_python_zeromq\lib\site-packages\ipykernel_launcher.py:12: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if sys.path[0] == '':
# File: Knot_Tying_B005.txt
# File: Knot_Tying_C001.txt
# File: Knot_Tying_C002.txt
# File: Knot_Tying_C003.txt
# File: Knot_Tying_C004.txt
# File: Knot_Tying_C005.txt
# File: Knot_Tying_D001.txt
# File: Knot_Tying_D002.txt
# File: Knot_Tying_D003.txt
# File: Knot_Tying_D004.txt
# File: Knot_Tying_D005.txt
# File: Knot_Tying_E001.txt
# File: Knot_Tying_E002.txt
# File: Knot_Tying_E003.txt
# File: Knot_Tying_E004.txt
# File: Knot_Tying_E005.txt
# File: Knot_Tying_F001.txt
# File: Knot_Tying_F002.txt
# File: Knot_Tying_F003.txt
# File: Knot_Tying_F004.txt
# File: Knot_Tying_F005.txt
# File: Knot_Tying_G001.txt
# File: Knot_Tying_G002.txt
# File: Knot_Tying_G003.txt
# File: Knot_Tying_G004.txt
# File: Knot_Tying_G005.txt
# File: Knot_Tying_H001.txt
# File: Knot_Tying_H002.txt
# File: Knot_Tying_H003.txt
# File: Knot_Tying_H004.txt
# File: Knot_Tying_H005.txt
# File: Knot_Tying_I001.txt
# File: Knot_Tying_I002.txt
# File: Knot_Tying_I003.txt
# File: Knot_Tying_I004.txt
# File: Knot_Tying_I005.txt
#       m_l_x     m_l_y     m_l_z   m_l_r00   m_l_r01   m_l_r02   m_l_r10  \
# 0  0.111180 -0.033020  0.415991 -0.421266  0.609012 -0.672075 -0.699657
# 1  0.111543 -0.032800  0.415891 -0.421579  0.608902 -0.671979 -0.700449
# 2  0.112342 -0.032401  0.415759 -0.424283  0.607637 -0.671422 -0.702506
# 3  0.113310 -0.032094  0.415662 -0.426768  0.606486 -0.670888 -0.704741
# 4  0.114262 -0.031781  0.415619 -0.430317  0.607002 -0.668147 -0.707102
#
#     m_l_r11   m_l_r12   m_l_r20  ...   s_r_r20   s_r_r21   s_r_r22    s_r_vx  \
# 0 -0.689689 -0.186497 -0.576585  ... -0.634914  0.250473  0.730853  0.007652
# 1 -0.689239 -0.185181 -0.575394  ... -0.633964  0.251593  0.731292  0.014519
# 2 -0.688674 -0.179403 -0.570882  ... -0.630072  0.255227  0.733394  0.014602
# 3 -0.687873 -0.173617 -0.566258  ... -0.626092  0.259099  0.735442  0.014518
# 4 -0.686711 -0.168541 -0.560601  ... -0.621140  0.260618  0.739096  0.014468
#
#      s_r_vy    s_r_vz   s_r_avx   s_r_avy   s_r_avz   s_r_ang
# 0  0.006507 -0.003909  0.046381 -0.039598  0.080345 -0.214419
# 1  0.001618  0.001034  0.007131 -0.039824  0.088421 -0.203969
# 2  0.006128 -0.004220  0.045144 -0.053541  0.108663 -0.184047
# 3  0.001836  0.001153  0.010400 -0.041345  0.091345 -0.185680
# 4  0.001683  0.001018 -2.019298  0.839852 -1.606168 -0.199723
#
# [5 rows x 76 columns]

# %%
# Summarize data from all samples
df = pd.concat(samples, axis=0, ignore_index=True)

# for i in range(1,len(samples)):
#     print("i = %d", i)
#     df.append(samples[i])
    
print("Total len of df: %d", df.shape[0])
df.info()
# Out:
# Total len of df: %d 68581
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68581 entries, 0 to 68580
# Data columns (total 76 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   m_l_x    68581 non-null  float64
#  1   m_l_y    68581 non-null  float64
#  2   m_l_z    68581 non-null  float64
#  3   m_l_r00  68581 non-null  float64
#  4   m_l_r01  68581 non-null  float64
#  5   m_l_r02  68581 non-null  float64
#  6   m_l_r10  68581 non-null  float64
#  7   m_l_r11  68581 non-null  float64
#  8   m_l_r12  68581 non-null  float64
#  9   m_l_r20  68581 non-null  float64
#  10  m_l_r21  68581 non-null  float64
#  11  m_l_r22  68581 non-null  float64
#  12  m_l_vx   68581 non-null  float64
#  13  m_l_vy   68581 non-null  float64
#  14  m_l_vz   68581 non-null  float64
#  15  m_l_avx  68581 non-null  float64
#  16  m_l_avy  68581 non-null  float64
#  17  m_l_avz  68581 non-null  float64
#  18  m_l_ang  68581 non-null  float64
#  19  m_r_x    68581 non-null  float64
#  20  m_r_y    68581 non-null  float64
#  21  m_r_z    68581 non-null  float64
#  22  m_r_r00  68581 non-null  float64
#  23  m_r_r01  68581 non-null  float64
#  24  m_r_r02  68581 non-null  float64
#  25  m_r_r10  68581 non-null  float64
#  26  m_r_r11  68581 non-null  float64
#  27  m_r_r12  68581 non-null  float64
#  28  m_r_r20  68581 non-null  float64
#  29  m_r_r21  68581 non-null  float64
#  30  m_r_r22  68581 non-null  float64
#  31  m_r_vx   68581 non-null  float64
#  32  m_r_vy   68581 non-null  float64
#  33  m_r_vz   68581 non-null  float64
#  34  m_r_avx  68581 non-null  float64
#  35  m_r_avy  68581 non-null  float64
#  36  m_r_avz  68581 non-null  float64
#  37  m_r_ang  68581 non-null  float64
#  38  s_l_x    68581 non-null  float64
#  39  s_l_y    68581 non-null  float64
#  40  s_l_z    68581 non-null  float64
#  41  s_l_r00  68581 non-null  float64
#  42  s_l_r01  68581 non-null  float64
#  43  s_l_r02  68581 non-null  float64
#  44  s_l_r10  68581 non-null  float64
#  45  s_l_r11  68581 non-null  float64
#  46  s_l_r12  68581 non-null  float64
#  47  s_l_r20  68581 non-null  float64
#  48  s_l_r21  68581 non-null  float64
#  49  s_l_r22  68581 non-null  float64
#  50  s_l_vx   68581 non-null  float64
#  51  s_l_vy   68581 non-null  float64
#  52  s_l_vz   68581 non-null  float64
#  53  s_l_avx  68581 non-null  float64
#  54  s_l_avy  68581 non-null  object
#  55  s_l_avz  68581 non-null  float64
#  56  s_l_ang  68581 non-null  float64
#  57  s_r_x    68581 non-null  float64
#  58  s_r_y    68581 non-null  float64
#  59  s_r_z    68581 non-null  float64
#  60  s_r_r00  68581 non-null  float64
#  61  s_r_r01  68581 non-null  float64
#  62  s_r_r02  68581 non-null  float64
#  63  s_r_r10  68581 non-null  float64
#  64  s_r_r11  68581 non-null  float64
#  65  s_r_r12  68581 non-null  float64
#  66  s_r_r20  68581 non-null  float64
#  67  s_r_r21  68581 non-null  float64
#  68  s_r_r22  68581 non-null  float64
#  69  s_r_vx   68581 non-null  float64
#  70  s_r_vy   68581 non-null  float64
#  71  s_r_vz   68581 non-null  float64
#  72  s_r_avx  68581 non-null  float64
#  73  s_r_avy  68581 non-null  float64
#  74  s_r_avz  68581 non-null  float64
#  75  s_r_ang  68579 non-null  float64
# dtypes: float64(75), object(1)
# memory usage: 39.8+ MB

# %%
df.describe()
# Out:
#               m_l_x         m_l_y         m_l_z       m_l_r00       m_l_r01  \
# count  68581.000000  68581.000000  68581.000000  68581.000000  68581.000000
# mean       0.124461      0.009079      0.368935     -0.291601      0.320308
# std        0.040701      0.032627      0.049383      0.423289      0.434538
# min        0.009905     -0.074547      0.235641     -0.999961     -0.939783
# 25%        0.097951     -0.013188      0.331274     -0.602317     -0.034199
# 50%        0.123724      0.010064      0.370824     -0.352744      0.394454
# 75%        0.148220      0.035720      0.407812     -0.075613      0.664081
# max        0.260390      0.106543      0.489780      0.991671      0.999562
#
#             m_l_r02       m_l_r10       m_l_r11       m_l_r12       m_l_r20  \
# count  68581.000000  68581.000000  68581.000000  68581.000000  68581.000000
# mean      -0.624748     -0.487864     -0.529507      0.003116     -0.466186
# std        0.232627      0.404250      0.488102      0.282700      0.341427
# min       -1.000006     -0.999613     -0.999984     -0.826323     -1.000012
# 25%       -0.809760     -0.825196     -0.895177     -0.202716     -0.720586
# 50%       -0.660523     -0.592404     -0.717235     -0.007563     -0.504704
# 75%       -0.455134     -0.211715     -0.339491      0.197948     -0.279327
# max        0.089227      0.999880      0.992894      0.939335      0.712897
#
#        ...       s_r_r20       s_r_r21       s_r_r22        s_r_vx  \
# count  ...  68581.000000  68581.000000  68581.000000  68581.000000
# mean   ...     -0.150033      0.104367      0.664248      0.000143
# std    ...      0.562574      0.381361      0.251888      0.013146
# min    ...     -0.999861     -0.991543     -0.543016     -0.145449
# 25%    ...     -0.605412     -0.162183      0.540827     -0.000597
# 50%    ...     -0.337955      0.153063      0.733974      0.000004
# 75%    ...      0.303258      0.420910      0.860789      0.005390
# max    ...      0.999571      0.971482      0.999753      0.101895
#
#              s_r_vy        s_r_vz       s_r_avx       s_r_avy       s_r_avz  \
# count  68581.000000  68581.000000  68581.000000  68581.000000  68581.000000
# mean       0.000523      0.000456      0.000876      0.013168     -0.007941
# std        0.008486      0.011989      0.693863      0.514297      0.684704
# min       -0.090549     -0.118528     -7.138607     -8.986909     -6.380124
# 25%       -0.001856     -0.001282     -0.021407     -0.019930     -0.027507
# 50%        0.000002      0.000002      0.000000     -0.000002      0.000012
# 75%        0.002391      0.003286      0.012022      0.029381      0.047696
# max        0.086518      0.155513      7.623260      6.728470      6.437808
#
#             s_r_ang
# count  68579.000000
# mean      -0.553343
# std        0.511834
# min       -1.177507
# 25%       -0.911997
# 50%       -0.829372
# 75%       -0.198989
# max        0.528226
#
# [8 rows x 75 columns]
